# %% [markdown]
# # Практика 1: исследовательские запросы к Common Crawl
#
# `run("...")` принимает те же аргументы, что `python main.py ...`. Всё скачанное сохраняется в `cache.json`, повторный запуск в сеть не ходит.

# %%
from main import run

# %% [markdown]
# ## 1. Пермь и Пермский Политех
# Найти страницы с упоминанием города Перми и ПНИПУ. Оценить распределение по доменам и датам.

# %%
run("--domain pstu.ru 59.ru properm.ru perm.aif.ru --text Перм* ПНИПУ --stats")
# Out:
# Поиск в pstu.ru/*, слова в адресе: не заданы...
# Поиск в 59.ru/*, слова в адресе: не заданы...
# Поиск в properm.ru/*, слова в адресе: не заданы...
# Поиск в perm.aif.ru/*, слова в адресе: не заданы...
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | URL                                                | Дата архивации   | Заголовок                      | Фрагмент текста                          |
# +====================================================+==================+================================+==========================================+
# | https://pstu.ru/about-the-university/development-  | 2026-07-12       | Стратегия и программы развития | в НОЦ «Рациональное недропользование» О  |
# | strategy-and-programs/nots-ratsionalnoe-           |                  |                                | программе Пермский национальный          |
# | nedropolzovanie/                                   |                  |                                | исследовательский политехнический        |
# |                                                    |                  |                                | университет — ключевой участник научно-  |
# |                                                    |                  |                                | образовательного центра мирового уровня  |
# |                                                    |                  |                                | «Рациональное н                          |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://pstu.ru/sveden/education/?act=discip&key={ | 2026-05-15       | Образование                    | я питания в образовательной организации  |
# | 6da2de74-32b9-41bf-90dc-e75cd973e325}              |                  |                                | Реквизиты ПНИПУ Лицензирование           |
# |                                                    |                  |                                | образовательных программ Информация об   |
# |                                                    |                  |                                | образовательных программах университета  |
# |                                                    |                  |                                | Среднее общее образование Бакалавр       |
# |                                                    |                  |                                | Магистр Специал                          |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://pstu.ru/sveden/education/?act=prakt&key={0 | 2026-02-11       | Образование                    | пная среда Международное сотрудничество  |
# | a107441-1f51-415c-b4e9-c8e50a66922c}               |                  |                                | Реквизиты ПНИПУ Информация об            |
# |                                                    |                  |                                | образовательных программах университета  |
# |                                                    |                  |                                | Среднее общее образование Бакалавр       |
# |                                                    |                  |                                | Магистр Специалист Аспирант Среднее      |
# |                                                    |                  |                                | общее образование К                      |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://pstu.ru/anons/2024/08/                     | 2025-10-06       | Анонсы за август 2024 года     | август сентябрь октябрь ноябрь декабрь   |
# |                                                    |                  |                                | 20.08.24 В Пермском Политехе пройдет     |
# |                                                    |                  |                                | всероссийская конференция                |
# |                                                    |                  |                                | «Математическое моделирование в          |
# |                                                    |                  |                                | естественных науках» Со 2 по 4 октября   |
# |                                                    |                  |                                | на базе Пермского Политеха               |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://pstu.ru/gallery/?gid=7745                  | 2025-10-14       | ОАО «Авиадвигатель» провел     | ов Ученого cовета по факультетам и       |
# |                                                    |                  | День открытых дверей!          | подразделениям ПНИПУ Список ученых       |
# |                                                    |                  |                                | советов секретарей факультетов и         |
# |                                                    |                  |                                | филиалов ПНИПУ План работы Ученого       |
# |                                                    |                  |                                | совета Нормативные документы             |
# |                                                    |                  |                                | Инструктивные материалы Документы        |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://pstu.ru/news/2013/04/17/1952/              | 2025-10-15       | В Пермском Политехе стартовала | В Пермском Политехе стартовала "Большая  |
# |                                                    |                  | "Большая разведка"             | разведка" Сегодня, 17 апреля , в 425     |
# |                                                    |                  |                                | аудитории главного корпуса Пермского     |
# |                                                    |                  |                                | национального исследовательского         |
# |                                                    |                  |                                | политехнического университета состоялось |
# |                                                    |                  |                                | открытие кон                             |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://pstu.ru/news/2014/11/19/3376/              | 2025-10-15       | В ПНИПУ пройдут ХI             | В ПНИПУ пройдут ХI Всероссийская         |
# |                                                    |                  | Всероссийская конференция      | конференция «БИОМЕХАНИКА-2014» и Школа-  |
# |                                                    |                  | «БИОМЕХАНИКА-2014» и Школа-    | семинар по биомеханике С 1 по 4 декабря  |
# |                                                    |                  | семинар по биомеханике         | 2014 года Пермский национальный          |
# |                                                    |                  |                                | исследовательский политехнический        |
# |                                                    |                  |                                | университет и кафедра                    |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://pstu.ru/news/2018/02/06/7844/              | 2025-10-18       | Проект ученых ПНИПУ и          | Проект ученых ПНИПУ и Индийского         |
# |                                                    |                  | Индийского технологического    | технологического института заинтересовал |
# |                                                    |                  | института заинтересовал        | предприятия российского ракетного и      |
# |                                                    |                  | предприятия российского        | авиадвигателестроения В конце ноября     |
# |                                                    |                  | ракетного и                    | 2017 года в Пермском Политехе прошла VI  |
# |                                                    |                  | авиадвигателестроения          | международная                            |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://pstu.ru/news/2021/03/18/11276/             | 2025-10-05       | В Пермском Политехе наградили  | В Пермском Политехе наградили лучших     |
# |                                                    |                  | лучших изобретателей           | изобретателей В Пермском Политехе        |
# |                                                    |                  |                                | наградили победителей конкурса проектов  |
# |                                                    |                  |                                | «Изобретатели ПНИПУ». Мероприятие        |
# |                                                    |                  |                                | организует Управление инноваций с целью  |
# |                                                    |                  |                                | популяризации и                          |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://pstu.ru/news/2023/11/28/14733/             | 2025-10-10       | Пена и руда: ученые ПНИПУ      | Пена и руда: ученые ПНИПУ выяснили, как  |
# |                                                    |                  | выяснили, как улучшить         | улучшить обогащение калийной руды В      |
# |                                                    |                  | обогащение калийной руды       | настоящее время на обогатительных        |
# |                                                    |                  |                                | калийных фабриках применяют метод пенной |
# |                                                    |                  |                                | флотации для отделения ценного продукта  |
# |                                                    |                  |                                | (хлорида                                 |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
#
# Найдено результатов: 36, показано: 10
#
# +-------------+-----------+
# | Домен       |   Страниц |
# +=============+===========+
# | pstu.ru     |        35 |
# +-------------+-----------+
# | perm.aif.ru |         1 |
# +-------------+-----------+
#
# +-------------------+-----------+
# | Месяц архивации   |   Страниц |
# +===================+===========+
# | 2025-05           |         1 |
# +-------------------+-----------+
# | 2025-06           |         4 |
# +-------------------+-----------+
# | 2025-07           |         4 |
# +-------------------+-----------+
# | 2025-08           |         4 |
# +-------------------+-----------+
# | 2025-09           |         9 |
# +-------------------+-----------+
# | 2025-10           |        10 |
# +-------------------+-----------+
# | 2026-02           |         1 |
# +-------------------+-----------+
# | 2026-05           |         1 |
# +-------------------+-----------+
# | 2026-07           |         2 |
# +-------------------+-----------+

# %% [markdown]
# ## 2. Кафедра ИТАС ПНИПУ
# Поиск упоминаний кафедры информационных технологий и автоматизированных систем.

# %%
run("etf --domain pstu.ru --text ИТАС --stats")
# Out:
# Поиск в pstu.ru/*, слова в адресе: ['etf']...
# +----------------------------------------------------+------------------+------------------------------+------------------------------------------+
# | URL                                                | Дата архивации   | Заголовок                    | Фрагмент текста                          |
# +====================================================+==================+==============================+==========================================+
# | https://pstu.ru/title1/faculties/etf/              | 2025-11-17       | Электротехнический факультет | ационные технологии и автоматизированные |
# |                                                    |                  |                              | системы (ИТАС) Кафедра Конструирование и |
# |                                                    |                  |                              | технологии в электротехнике (КТЭ)        |
# |                                                    |                  |                              | Кафедра Микропроцессорные средства       |
# |                                                    |                  |                              | автоматизации (МСА) Кафедра              |
# |                                                    |                  |                              | Электротехника и элек                    |
# +----------------------------------------------------+------------------+------------------------------+------------------------------------------+
# | https://pstu.ru/title1/faculties/etf/at/?staff=1&s | 2025-11-16       | Кафедра Автоматика и         | ационные технологии и автоматизированные |
# | id=-3147&cid=79                                    |                  | телемеханика (АТ)            | системы (ИТАС) Кафедра Конструирование и |
# |                                                    |                  |                              | технологии в электротехнике (КТЭ)        |
# |                                                    |                  |                              | Кафедра Микропроцессорные средства       |
# |                                                    |                  |                              | автоматизации (МСА) Кафедра              |
# |                                                    |                  |                              | Электротехника и элек                    |
# +----------------------------------------------------+------------------+------------------------------+------------------------------------------+
# | https://pstu.ru/title1/faculties/etf/at/?staff=1&s | 2025-11-13       | Кафедра Автоматика и         | ационные технологии и автоматизированные |
# | id=-3883&cid=79                                    |                  | телемеханика (АТ)            | системы (ИТАС) Кафедра Конструирование и |
# |                                                    |                  |                              | технологии в электротехнике (КТЭ)        |
# |                                                    |                  |                              | Кафедра Микропроцессорные средства       |
# |                                                    |                  |                              | автоматизации (МСА) Кафедра              |
# |                                                    |                  |                              | Электротехника и элек                    |
# +----------------------------------------------------+------------------+------------------------------+------------------------------------------+
# | https://pstu.ru/title1/faculties/etf/at/?staff=1&s | 2025-11-17       | Кафедра Автоматика и         | ационные технологии и автоматизированные |
# | id=-939&cid=79                                     |                  | телемеханика (АТ)            | системы (ИТАС) Кафедра Конструирование и |
# |                                                    |                  |                              | технологии в электротехнике (КТЭ)        |
# |                                                    |                  |                              | Кафедра Микропроцессорные средства       |
# |                                                    |                  |                              | автоматизации (МСА) Кафедра              |
# |                                                    |                  |                              | Электротехника и элек                    |
# +----------------------------------------------------+------------------+------------------------------+------------------------------------------+
# | https://pstu.ru/title1/faculties/etf/at/?staff=1&s | 2025-11-17       | Кафедра Автоматика и         | ационные технологии и автоматизированные |
# | id=1455&cid=79                                     |                  | телемеханика (АТ)            | системы (ИТАС) Кафедра Конструирование и |
# |                                                    |                  |                              | технологии в электротехнике (КТЭ)        |
# |                                                    |                  |                              | Кафедра Микропроцессорные средства       |
# |                                                    |                  |                              | автоматизации (МСА) Кафедра              |
# |                                                    |                  |                              | Электротехника и элек                    |
# +----------------------------------------------------+------------------+------------------------------+------------------------------------------+
# | https://pstu.ru/title1/faculties/etf/itas/?pc_vers | 2025-11-13       | Кафедра Информационные       | ационные технологии и автоматизированные |
# | ion=1                                              |                  | технологии и                 | системы (ИТАС) Кафедра Конструирование и |
# |                                                    |                  | автоматизированные системы   | технологии в электротехнике (КТЭ)        |
# |                                                    |                  | (ИТАС)                       | Кафедра Микропроцессорные средства       |
# |                                                    |                  |                              | автоматизации (МСА) Кафедра              |
# |                                                    |                  |                              | Электротехника и элек                    |
# +----------------------------------------------------+------------------+------------------------------+------------------------------------------+
# | https://pstu.ru/title1/faculties/etf/?about=1&cid= | 2025-11-09       | Кафедра Автоматика и         | ационные технологии и автоматизированные |
# | 79                                                 |                  | телемеханика (АТ)            | системы (ИТАС) Кафедра Конструирование и |
# |                                                    |                  |                              | технологии в электротехнике (КТЭ)        |
# |                                                    |                  |                              | Кафедра Микропроцессорные средства       |
# |                                                    |                  |                              | автоматизации (МСА) Кафедра              |
# |                                                    |                  |                              | Электротехника и элек                    |
# +----------------------------------------------------+------------------+------------------------------+------------------------------------------+
# | https://pstu.ru/title1/faculties/etf/?diraspec=1&c | 2025-11-09       | Кафедра Автоматика и         | ационные технологии и автоматизированные |
# | id=79                                              |                  | телемеханика (АТ)            | системы (ИТАС) Кафедра Конструирование и |
# |                                                    |                  |                              | технологии в электротехнике (КТЭ)        |
# |                                                    |                  |                              | Кафедра Микропроцессорные средства       |
# |                                                    |                  |                              | автоматизации (МСА) Кафедра              |
# |                                                    |                  |                              | Электротехника и элек                    |
# +----------------------------------------------------+------------------+------------------------------+------------------------------------------+
# | https://pstu.ru/title1/faculties/etf/?science=1&ci | 2025-11-19       | Кафедра Автоматика и         | ационные технологии и автоматизированные |
# | d=79                                               |                  | телемеханика (АТ)            | системы (ИТАС) Кафедра Конструирование и |
# |                                                    |                  |                              | технологии в электротехнике (КТЭ)        |
# |                                                    |                  |                              | Кафедра Микропроцессорные средства       |
# |                                                    |                  |                              | автоматизации (МСА) Кафедра              |
# |                                                    |                  |                              | Электротехника и элек                    |
# +----------------------------------------------------+------------------+------------------------------+------------------------------------------+
# | https://pstu.ru/title1/faculties/etf/?sources=1&ci | 2025-11-19       | Кафедра Автоматика и         | ационные технологии и автоматизированные |
# | d=79                                               |                  | телемеханика (АТ)            | системы (ИТАС) Кафедра Конструирование и |
# |                                                    |                  |                              | технологии в электротехнике (КТЭ)        |
# |                                                    |                  |                              | Кафедра Микропроцессорные средства       |
# |                                                    |                  |                              | автоматизации (МСА) Кафедра              |
# |                                                    |                  |                              | Электротехника и элек                    |
# +----------------------------------------------------+------------------+------------------------------+------------------------------------------+
#
# Найдено результатов: 30, показано: 10
#
# +---------+-----------+
# | Домен   |   Страниц |
# +=========+===========+
# | pstu.ru |        30 |
# +---------+-----------+
#
# +-------------------+-----------+
# | Месяц архивации   |   Страниц |
# +===================+===========+
# | 2025-06           |         1 |
# +-------------------+-----------+
# | 2025-07           |         7 |
# +-------------------+-----------+
# | 2025-08           |         5 |
# +-------------------+-----------+
# | 2025-09           |         4 |
# +-------------------+-----------+
# | 2025-10           |         1 |
# +-------------------+-----------+
# | 2025-11           |        12 |
# +-------------------+-----------+

# %% [markdown]
# ## 3. МГУ vs МФТИ
# Сравнить количество и характер упоминаний двух ведущих вузов России в веб-архиве.

# %%
run("--domain ru.wikipedia.org --prefix wiki/Московский_ --count МГУ МФТИ")
# Out:
# Поиск в ru.wikipedia.org/wiki/Московский_*, слова в адресе: не заданы...
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | URL                                                | Дата архивации   | Заголовок                      | Фрагмент текста                          |
# +====================================================+==================+================================+==========================================+
# | https://ru.wikipedia.org/wiki/Московский_городской | 2026-08-10       | Институт Склифосовского —      | ГБУЗ «Научно-исследовательский институт  |
# | _научно-исследовательский_институт_скорой_помощи_и |                  | Википедия                      | скорой помощи имени Н. В. Склифосовского |
# | мени_Н._В._Склифосовского                          |                  |                                | Департамента здравоохранения города      |
# |                                                    |                  |                                | Москвы» (ГБУЗ «НИИ СП им. Н. В.          |
# |                                                    |                  |                                | Склифосовского ДЗМ») Здание бывшей       |
# |                                                    |                  |                                | Шереметевской бо                         |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://ru.wikipedia.org/wiki/Московский_аэровокза | 2026-07-19       | Московский аэровокзал —        | Аэровокзал Бывший диспетчерский пункт    |
# | л                                                  |                  | Википедия                      | аэровокзала, 2010 год 55°47′36″ с. ш.    |
# |                                                    |                  |                                | 37°32′34″ в. д. H G Я O Тип Здание       |
# |                                                    |                  |                                | Страна Россия Город Москва Архитектор    |
# |                                                    |                  |                                | Д. Бурдин , Л. Баталов , Ю. Рабаев ,     |
# |                                                    |                  |                                | М. Артемьев ,                            |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://ru.wikipedia.org/wiki/Московский_инженерно | 2026-06-14       | Национальный исследовательский | та за 2017 год является одним из лидеров |
# | -физический_институт                               |                  | ядерный университет «МИФИ» —   | наряду с МФТИ , НИТУ «МИСиС» , НГУ , НИУ |
# |                                                    |                  | Википедия                      | ВШЭ , НИУ ИТМО и ТГУ [ 14 ] . Совместно  |
# |                                                    |                  |                                | с ВАВТ запустил образовательную          |
# |                                                    |                  |                                | программу «двойного диплома» по          |
# |                                                    |                  |                                | направлениям «                           |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://ru.wikipedia.org/wiki/Московский_механизм_ | 2026-06-12       | Московский механизм ОБСЕ —     | Московский механизм ОБСЕ — метод работы  |
# | ОБСЕ                                               |                  | Википедия                      | ОБСЕ в области человеческого измерения   |
# |                                                    |                  |                                | по инициативе стран-участниц. Включает   |
# |                                                    |                  |                                | создание миссий экспертов или            |
# |                                                    |                  |                                | докладчиков для работы с положением с    |
# |                                                    |                  |                                | человеческим и                           |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://ru.wikipedia.org/wiki/Московский_математич | 2026-05-17       | Московский математический      | Четырнадцатая задача Московского         |
# | еский_папирус                                      |                  | папирус — Википедия            | математического папируса (Struve 1930).  |
# |                                                    |                  |                                | Наверху иератический текст, внизу        |
# |                                                    |                  |                                | иероглифическая транскрипция. Текст      |
# |                                                    |                  |                                | читается справа налево Московский        |
# |                                                    |                  |                                | математический папирус                   |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://ru.wikipedia.org/wiki/Московский_3-й_кадет | 2026-05-16       | Московский 3-й кадетский       | 3-й Московский кадетский корпус Знамя    |
# | ский_корпус                                        |                  | корпус — Википедия             | 3-го Московского Императора Александра   |
# |                                                    |                  |                                | II кадетского корпуса Годы существования |
# |                                                    |                  |                                | 1867 — 1918 Страна Российская империя    |
# |                                                    |                  |                                | Тип кадетский корпус Функция подготовка  |
# |                                                    |                  |                                | двор                                     |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://ru.wikipedia.org/wiki/Московский_государст | 2026-04-14       | Российский университет         | ов по количеству студентов вошли МФПУ    |
# | венный_университет_путей_сообщения                 |                  | транспорта — Википедия         | "Синергия", МГУ и УрФУ (рус.) .          |
# |                                                    |                  |                                | Российская газета (7 декабря 2023). Дата |
# |                                                    |                  |                                | обращения: 25 октября 2024. Архивировано |
# |                                                    |                  |                                | 6 октября 2024 года. ↑ МИИТ > Об         |
# |                                                    |                  |                                | университете >                           |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://ru.wikipedia.org/wiki/Московский_Новый_дра | 2026-03-12       | Московский Новый драматический | Московский Новый драматический театр     |
# | матический_театр                                   |                  | театр — Википедия              | Основан 1 августа 1975 Здание театра     |
# |                                                    |                  |                                | Местоположение Россия , Москва Адрес     |
# |                                                    |                  |                                | улица Проходчиков , 2 Руководство        |
# |                                                    |                  |                                | Директор Вера Поповичева Художественный  |
# |                                                    |                  |                                | руководитель Вя                          |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://ru.wikipedia.org/wiki/Московский_государст | 2026-03-13       | Мытищинский филиал МГТУ имени  | , С. А. Чаплыгин (механика),             |
# | венный_университет_леса                            |                  | Н. Э. Баумана — Википедия      | В. П. Волгин, ректор МГУ (политучения).  |
# |                                                    |                  |                                | По числу студентов самым многочисленным  |
# |                                                    |                  |                                | был Лесоинженерный факультет, который    |
# |                                                    |                  |                                | насчитывал 903 студента. На              |
# |                                                    |                  |                                | Лесохозяйственном факульт                |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
# | https://ru.wikipedia.org/wiki/Московский_междунаро | 2026-03-10       | Московский международный       | силовых структур Московский им. М. В.    |
# | дный_университет                                   |                  | университет — Википедия        | Ломоносова МГУ Авиационный МАИ           |
# |                                                    |                  |                                | Автомобильно-дорожный МАДИ Аграрный      |
# |                                                    |                  |                                | РГАУ-МСХА им. К. А. Тимирязева           |
# |                                                    |                  |                                | Биотехнологический РОСБИОТЕХ Военный ВУ  |
# |                                                    |                  |                                | им. князя Александра Не                  |
# +----------------------------------------------------+------------------+--------------------------------+------------------------------------------+
#
# Найдено результатов: 40, показано: 10
#
# Страниц проверено: 40
# +---------+-----------+--------------+
# | Слово   |   Страниц |   Упоминаний |
# +=========+===========+==============+
# | МГУ     |        17 |           25 |
# +---------+-----------+--------------+
# | МФТИ    |        13 |           15 |
# +---------+-----------+--------------+

# %% [markdown]
# ## 4. Борис Пастернак + Пермь
# Исследовать контекст упоминания поэта в связи с городом.

# %%
run("--domain ru.wikipedia.org --prefix wiki/Пастернак --text Перм*")
# Out:
# Поиск в ru.wikipedia.org/wiki/Пастернак*, слова в адресе: не заданы...
# +----------------------------------------------------+------------------+-------------------------------+---------------------------------------+
# | URL                                                | Дата архивации   | Заголовок                     | Фрагмент текста                       |
# +====================================================+==================+===============================+=======================================+
# | https://ru.wikipedia.org/wiki/Пастернак,_Борис_Лео | 2025-12-09       | Пастернак, Борис Леонидович — | нак провёл на Урале , под городом     |
# | нидович                                            |                  | Википедия                     | Александровском Пермской губернии , в |
# |                                                    |                  |                               | посёлке Всеволодо-Вильва , приняв     |
# |                                                    |                  |                               | приглашение поработать в конторе      |
# |                                                    |                  |                               | управляющего Всеволодо-Вильвенскими   |
# |                                                    |                  |                               | химическими заводами Бори             |
# +----------------------------------------------------+------------------+-------------------------------+---------------------------------------+
#
# Найдено результатов: 1, показано: 1
